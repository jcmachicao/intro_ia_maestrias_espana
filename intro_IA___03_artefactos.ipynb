# %%
# Otros artefactos JSON que puedes generar

# A. Esquema de brechas
{
  "expectativa_cliente": "",
  "ofrecimiento_proveedor": "",
  "realidad_observada": "",
  "tipo_brecha": "",
  "severidad": ""
}

# B. Perfil cognitivo del caso
{
  "funciones_activadas": [
    "comparacion",
    "evaluacion",
    "priorizacion"
  ],
  "nivel_incertidumbre": "",
  "grado_de_ambiguedad": ""
}

# C. Nodo de decisión
{
  "condicion": "",
  "criterios_evaluacion": [],
  "opciones_posibles": [],
  "regla_de_seleccion": ""
}

# D. Catálogo de acciones organizacionales
{
  "accion_id": "",
  "descripcion": "",
  "condiciones_de_aplicacion": [],
  "costo_estimado": "",
  "impacto_en_confianza": ""
}

# E. Registro de experimentación
{
  "version_ontologia": "",
  "casos_probados": [],
  "errores_detectados": [],
  "ajustes_realizados": []
}
# Out:
# {'version_ontologia': '',
#  'casos_probados': [],
#  'errores_detectados': [],
#  'ajustes_realizados': []}
