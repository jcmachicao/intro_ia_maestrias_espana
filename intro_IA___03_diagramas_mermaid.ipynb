# %%
prompt_mermaid = """
Quiero que generes un diagrama en sintaxis Mermaid que represente un workflow cognitivo para el procesamiento general de quejas de clientes.

Requisitos:
Máximo 10 nodos.
Debe ser un flujo secuencial con al menos un nodo de decisión.
Cada nodo debe representar una función cognitiva explícita (por ejemplo: percepción, memoria, comparación, evaluación, criterio, reflexión, priorización, decisión).

El sistema debe incluir:
recepción de la queja
identificación de expectativa del cliente
descripción de la situación real
contraste entre expectativa y realidad
aplicación de criterios organizacionales
selección de una acción posible
Usa nombres claros y breves en los nodos.

No agregues explicaciones fuera del código Mermaid.
Devuelve únicamente el bloque de código Mermaid.

El enfoque debe ser cognitivo (procesamiento mental y toma de decisiones), no técnico ni informático.
"""

# %% [markdown]
# ![Mermaid Chart - Create complex, visual diagrams with text.-2026-02-14-124938.png](data:image/png;base64,...)
